# %%
nombre = input('¿Cuál es tu nombre(s)?')
apellido_paterno = input('¿Cuál es tu apellido paterno?')
apellido_materno = input('¿Cuál es tu apellido materno?')

# %%
nombre_completo = nombre, apellido_paterno, apellido_materno

# %%
edad = int(input('¿Cuál  es tu edad?'))
peso = int(input('¿Cuál es tu peso?'))
estatura = float(input('¿Cuál es tu estatura?'))

# %%
imc=peso/estatura**2

# %%
print(f"""{" ".join(nombre_completo).title()}
Edad: {edad}
Estatura: {estatura}
Peso: {peso}\nIMC: {imc:.2f}
Gracias por usar esta calculadora.
""")
# Out:
# Jesús Tomás Loera Porras
# Edad: 22
# Estatura: 1.65
# Peso: 56
# IMC: 20.57
# Gracias por usar esta calculadora.
